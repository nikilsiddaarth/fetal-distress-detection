# %%
annotation_columns = [
    "A", "B", "C", "D", "E",
    "AD", "DE", "LD", "FS", "SUSP",
    "CLASS"
]

df_clean = df.drop(columns=annotation_columns)

print("Removed columns:")
print(annotation_columns)

print("\nFinal columns:")
print(df_clean.columns.tolist())

print("\nFinal shape:", df_clean.shape)
# Out:
# Removed columns:
# ['A', 'B', 'C', 'D', 'E', 'AD', 'DE', 'LD', 'FS', 'SUSP', 'CLASS']
#
# Final columns:
# ['b', 'e', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'DR', 'LB', 'AC.1', 'FM.1', 'UC.1', 'DL.1', 'DS.1', 'DP.1', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Min', 'Max', 'Nmax', 'Nzeros', 'Mode', 'Mean', 'Median', 'Variance', 'Tendency', 'NSP']
#
# Final shape: (2129, 31)

# %%
X = df_clean.drop(columns=["NSP"])
y = df_clean["NSP"]

print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nTarget distribution:")
print(y.value_counts().sort_index())
# Out:
# X shape: (2129, 30)
# y shape: (2129,)
#
# Target distribution:
# NSP
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("X_train shape:", X_train.shape)
print("X_test shape :", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape :", y_test.shape)

print("\nTraining class distribution:")
print(y_train.value_counts().sort_index())

print("\nTesting class distribution:")
print(y_test.value_counts().sort_index())
# Out:
# X_train shape: (1700, 30)
# X_test shape : (426, 30)
# y_train shape: (1700,)
# y_test shape : (426,)
#
# Training class distribution:
# NSP
# 1.0    1323
# 2.0     236
# 3.0     141
# Name: count, dtype: int64
#
# Testing class distribution:
# NSP
# 1.0    332
# 2.0     59
# 3.0     35
# Name: count, dtype: int64

# %%
import os

os.makedirs("../data/processed", exist_ok=True)

X_train.to_csv("../data/processed/X_train.csv", index=False)
X_test.to_csv("../data/processed/X_test.csv", index=False)
y_train.to_csv("../data/processed/y_train.csv", index=False)
y_test.to_csv("../data/processed/y_test.csv", index=False)

print("✅ CLEAN PROCESSED DATA SAVED")
print("Features:", X_train.shape[1])
print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))
# Out:
# ✅ CLEAN PROCESSED DATA SAVED
# Features: 30
# Training rows: 1700
# Testing rows: 426

# %%
print("Missing NSP values:", y.isna().sum())
# Out:
# Missing NSP values: 3

# %%
# Remove rows where the target NSP is missing
valid_rows = y.notna()

X = X.loc[valid_rows].copy()
y = y.loc[valid_rows].copy()

print("X shape after removing missing targets:", X.shape)
print("y shape after removing missing targets:", y.shape)

print("\nTarget distribution:")
print(y.value_counts().sort_index())
# Out:
# X shape after removing missing targets: (2126, 30)
# y shape after removing missing targets: (2126,)
#
# Target distribution:
# NSP
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: count, dtype: int64

# %%
# Remove columns that are completely empty
df = df.dropna(axis=1, how="all")

print("Shape after removing empty columns:", df.shape)
print("\nRemaining columns:")
print(df.columns.tolist())
# Out:
# Shape after removing empty columns: (2129, 42)
#
# Remaining columns:
# ['b', 'e', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'DR', 'LB', 'AC.1', 'FM.1', 'UC.1', 'DL.1', 'DS.1', 'DP.1', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Min', 'Max', 'Nmax', 'Nzeros', 'Mode', 'Mean', 'Median', 'Variance', 'Tendency', 'A', 'B', 'C', 'D', 'E', 'AD', 'DE', 'LD', 'FS', 'SUSP', 'CLASS', 'NSP']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load original CTG dataset
df = pd.read_excel("../data/CTG.xls", sheet_name="Data", header=1)

print("Original shape:", df.shape)
print("Original columns:")
print(df.columns.tolist())
# Out:
# Original shape: (2129, 46)
# Original columns:
# ['b', 'e', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'DR', 'Unnamed: 9', 'LB', 'AC.1', 'FM.1', 'UC.1', 'DL.1', 'DS.1', 'DP.1', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Min', 'Max', 'Nmax', 'Nzeros', 'Mode', 'Mean', 'Median', 'Variance', 'Tendency', 'Unnamed: 31', 'A', 'B', 'C', 'D', 'E', 'AD', 'DE', 'LD', 'FS', 'SUSP', 'Unnamed: 42', 'CLASS', 'Unnamed: 44', 'NSP']
